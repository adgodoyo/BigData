# %%
import pandas as pd

# %%
# Ruta del archivo Parquet
file_path = 'yellow_tripdata_2024-05.parquet'

# Cargar el archivo Parquet
data = pd.read_parquet(file_path)

# %%
data
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2024-05-01 00:59:15   2024-05-01 01:23:50              1.0
# 1               2  2024-04-30 23:58:26   2024-05-01 00:29:42              1.0
# 2               2  2024-05-01 00:57:17   2024-05-01 01:14:15              1.0
# 3               2  2024-05-01 00:24:47   2024-05-01 00:48:51              1.0
# 4               2  2024-05-01 00:11:20   2024-05-01 00:52:10              1.0
# ...           ...                  ...                   ...              ...
# 3723828         2  2024-05-31 23:45:00   2024-06-01 00:09:00              NaN
# 3723829         2  2024-05-31 23:10:52   2024-05-31 23:38:05              NaN
# 3723830         2  2024-05-31 23:23:57   2024-05-31 23:38:35              NaN
# 3723831         2  2024-05-31 23:44:12   2024-05-31 23:47:44              NaN
# 3723832         2  2024-05-31 23:11:10   2024-05-31 23:38:27              NaN
#
# ...

# %%
data.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge', 'Airport_fee'],
#       dtype='object')

# %%
import pandas as pd
from sqlalchemy import create_engine
import time

# %%
while True:
        # Crear una conexión a la base de datos SQLite
    engine = create_engine('sqlite:///../taxi_rides.db')
    # Leer la tabla `taxi_rides` en un DataFrame
    df = pd.read_sql_table('taxi_rides', engine)
    print(df[['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime']].tail(10))
    time.sleep(2)
# Out:
#         VendorID tpep_pickup_datetime tpep_dropoff_datetime
# 221990         2  2024-01-04 16:40:03   2024-01-04 16:56:55
# 221991         2  2024-01-04 16:24:45   2024-01-04 17:12:51
# 221992         2  2024-01-04 16:05:55   2024-01-04 16:19:08
# 221993         2  2024-01-04 16:39:59   2024-01-04 17:05:54
# 221994         2  2024-01-04 16:39:22   2024-01-04 17:01:12
# 221995         2  2024-01-04 16:39:22   2024-01-04 17:01:12
# 221996         1  2024-01-04 16:56:58   2024-01-04 17:29:34
# 221997         1  2024-01-04 16:06:26   2024-01-04 16:31:18
# 221998         1  2024-01-04 16:00:37   2024-01-04 16:02:16
# 221999         1  2024-01-04 16:24:49   2024-01-04 16:41:32
#         VendorID tpep_pickup_datetime tpep_dropoff_datetime
# 224990         2  2024-01-04 17:00:45   2024-01-04 17:19:48
# 224991         2  2024-01-04 17:39:47   2024-01-04 18:01:22
# 224992         2  2024-01-04 17:06:18   2024-01-04 17:31:46
# 224993         1  2024-01-04 17:52:50   2024-01-04 19:03:21
# ...
